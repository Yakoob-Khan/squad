# %% [markdown]
# # CS 72 Accelerated Computational Linguistics
# ## Final Project
# ### Training the Baseline Model

# %% [markdown]
# Credits:
# * BiDAF code and data provided by: <https://github.com/minggg/squad>
#
# * GPU provided Google Co-lab: <https://colab.research.google.com/>
#
# * Google Colab notebook written and model trained by: Yakoob Khan '21 (Yakoob.Khan.21@dartmouth.edu)

# %% [markdown]
# # Bi-directional Attention Flow (BiDAF) model
# ### Image Credits: <https://allenai.github.io/bi-att-flow/>

# %% [markdown]
# <img src="../model-architectures/bidaf-model.png">

# %% [markdown]
# ## First we import the code into Google Colab by cloning the git repository

# %%
# !git clone https://github.com/Yakoob-Khan/squad
# Out:
# Cloning into 'squad'...
# remote: Enumerating objects: 53, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (46/46), done.
# remote: Total 97 (delta 16), reused 40 (delta 7), pack-reused 44
# Unpacking objects: 100% (97/97), done.

# %% [markdown]
# ## Now we change into the directory containing code for the baseline model

# %%
# %cd /content/squad
# Out:
# [Errno 2] No such file or directory: '/content/squad'
# /Users/yakoobkhan/Desktop/CS-72/Project/squad/baseline-model

# %% [markdown]
# ## We need to get and install the Anaconda Package as Google Colab does not have it by default.

# %%
# !wget -c https://repo.continuum.io/archive/Anaconda3-5.3.0-Linux-x86_64.sh

# !chmod +x Anaconda3-5.3.0-Linux-x86_64.sh

# !bash ./Anaconda3-5.3.0-Linux-x86_64.sh -b -f -p /usr/local

import sys

sys.path.append('/usr/local/lib/python3.6/site-packages/')
# Out:
# --2020-05-24 16:47:38--  https://repo.continuum.io/archive/Anaconda3-5.3.0-Linux-x86_64.sh
# Resolving repo.continuum.io (repo.continuum.io)... 104.18.200.79, 104.18.201.79, 2606:4700::6812:c94f, ...
# Connecting to repo.continuum.io (repo.continuum.io)|104.18.200.79|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://repo.anaconda.com/archive/Anaconda3-5.3.0-Linux-x86_64.sh [following]
# --2020-05-24 16:47:38--  https://repo.anaconda.com/archive/Anaconda3-5.3.0-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.131.3, 104.16.130.3, 2606:4700::6810:8303, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.131.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 667822837 (637M) [application/x-sh]
# Saving to: ‘Anaconda3-5.3.0-Linux-x86_64.sh’
#
# Anaconda3-5.3.0-Lin 100%[===================>] 636.88M   147MB/s    in 4.6s
#
# ...

# %%
# !conda --version
# Out:
# conda 4.8.3

# %% [markdown]
# # Update conda environment to the latest version.

# %%
# !conda update -n base conda
# Out:
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     libedit-3.1.20181209       |       hc058e9b_0         188 KB
#     pip-20.0.2                 |           py38_3         1.9 MB
#     python-3.8.3               |       hcff3b4d_0        57.3 MB
#     libgcc-ng-9.1.0            |       hdf63c60_0         8.1 MB
#     six-1.14.0                 |           py38_0          27 KB
#     conda-4.8.3                |           py38_0         3.0 MB
#     urllib3-1.25.8             |           py38_0         166 KB
#     setuptools-46.4.0          |           py38_0         656 KB
#     cryptography-2.9.2         |   py38h1ba5d50_0         630 KB
#     zlib-1.2.11                |       h7b6447c_3         120 KB
# ...

# %%
# !conda --version
# Out:
# conda 4.8.3

# %% [markdown]
# # Run environment.yml to create the "squad" conda environment.

# %%
# !conda env create -f environment.yml
# Out:
# done
# done
#
# ...
# absl-py-0.9.0        | 162 KB    | : 100% 1.0/1 [00:00<00:00,  5.93it/s]
# _libgcc_mutex-0.1    | 3 KB      | : 100% 1.0/1 [00:00<00:00, 19.47it/s]
# zlib-1.2.11          | 105 KB    | : 100% 1.0/1 [00:00<00:00, 18.05it/s]
# cymem-2.0.3          | 41 KB     | : 100% 1.0/1 [00:00<00:00,  3.23it/s]
# ld_impl_linux-64-2.3 | 608 KB    | : 100% 1.0/1 [00:00<00:00,  7.49it/s]
# pip-20.1.1           | 1.1 MB    | : 100% 1.0/1 [00:00<00:00,  4.29it/s]
# keras-preprocessing- | 33 KB     | : 100% 1.0/1 [00:00<00:00, 27.39it/s]
# mkl-2020.1           | 200.8 MB  | : 100% 1.0/1 [00:31<00:00, 31.20s/it]
# murmurhash-1.0.0     | 16 KB     | : 100% 1.0/1 [00:00<00:00, 21.56it/s]
# keras-applications-1 | 30 KB     | : 100% 1.0/1 [00:00<00:00, 19.17it/s]
# chardet-3.0.4        | 188 KB    | : 100% 1.0/1 [00:00<00:00, 12.68it/s]
# libpng-1.6.37        | 308 KB    | : 100% 1.0/1 [00:00<00:00, 12.01it/s]
# krb5-1.17.1          | 1.5 MB    | : 100% 1.0/1 [00:00<00:00,  4.02it/s]
# ...

# %% [markdown]
# # Check that the squad environment has been correctly installed.

# %%
# !conda info --envs
# Out:
# # conda environments:
# #
# base                  *  /usr/local
# squad                    /usr/local/envs/squad

# %% [markdown]
# # We need to change the bash.rc file so that we can run a bash shell inside a jupyter notebook cell

# %%
# !echo ". /usr/local/etc/profile.d/conda.sh" >> ~/.bashrc

# %% [markdown]
# ## Run "python setup.py" to download the GloVe word embeddings and pre-process the training and dev datasets. This process takes about 30 minutes.

# %%
# !bash -i
# Out:
# bash: cannot set terminal process group (2595): Inappropriate ioctl for device
# bash: no job control in this shell
# root@1fa96ba23b1b:/content# conda activate squad
# (squad) root@1fa96ba23b1b:/content# python setup.py
# python: can't open file 'setup.py': [Errno 2] No such file or directory
# (squad) root@1fa96ba23b1b:/content# ls
# sample_data  squad
# (squad) root@1fa96ba23b1b:/content# cd squad
# (squad) root@1fa96ba23b1b:/content/squad# ls
#  Anaconda3-5.3.0-Linux-x86_64.sh   data              models.py   test.py
#  args.py                           environment.yml   README.md   train.py
# 'Code Experiments.ipynb'           layers.py         save        util.py
#  CS_72_Final_Project.ipynb         LICENSE           setup.py
# (squad) root@1fa96ba23b1b:/content/squad# python setup.py
# ...
# glove.840B.300d.zip: 2.18GB [16:59, 2.14MB/s]
# Unzipping GloVe word vectors...
# ...
#      |████████████████████████████████| 37.4 MB 542 kB/s
# ...

# %% [markdown]
# ### We are ready to train the BiDAF model! Training takes about 10 minutes per epoch on a single GPU on Google Colab. We trained the model for 14 epochs for a total training time of about 2.5 hours.
# #### * DEV NLL is the development / validation set training loss.
# #### * F1 is the F1 Score.
# #### * EM is the Exact Match Score
# #### * Scroll all the way to the bottom to see the final F1 and EM score!

# %%
# !bash -i
# Out:
# bash: cannot set terminal process group (2595): Inappropriate ioctl for device
# bash: no job control in this shell
# root@1fa96ba23b1b:/content# conda activate squad
# (squad) root@1fa96ba23b1b:/content# ls
# sample_data  squad
# alse
# python: can't open file 'train.py': [Errno 2] No such file or directory
# (squad) root@1fa96ba23b1b:/content# cd squad
# (squad) root@1fa96ba23b1b:/content/squad# ls
#  Anaconda3-5.3.0-Linux-x86_64.sh   data              models.py     setup.py
#  args.py                           environment.yml   __pycache__   test.py
# 'Code Experiments.ipynb'           layers.py         README.md     train.py
#  CS_72_Final_Project.ipynb         LICENSE           save          util.py
# d_v2=False
# [05.24.20 18:00:34] Args: {
#     "batch_size": 64,
#     "char_emb_file": "./data/char_emb.json",
#     "dev_eval_file": "./data/dev_eval.json",
#     "dev_record_file": "./data/dev.npz",
#     "drop_prob": 0.2,
#     "ema_decay": 0.999,
#     "eval_steps": 50000,
# ...

# %% [markdown]
# ### Visualizing Validation Set Training Loss on Tensorboard!

# %% [markdown]
# <img src="../screen-captures/tensorboard-baseline-dev-loss.png">

# %% [markdown]
# # Final Results:
# ### * F1 Score: 78.98
# ### * EM Score: 69.73
